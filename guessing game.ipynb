# %%
import random

# Generate a random number between 1 and 100
secret_number = random.randint(1, 100)
attempts = 0

print("Welcome to the Number Guessing Game!")
print("I'm thinking of a number between 1 and 100.")

while True:
    guess = int(input("Enter your guess: "))
    attempts += 1

    if guess < secret_number:
        print("Too low! Try again.")
    elif guess > secret_number:
        print("Too high! Try again.")
    else:
        print(f"Correct! You guessed it in {attempts} attempts.")
        break
# Out:
# Think of a number between 1 and 100, and I'll try to guess it!
# Press Enter when you're ready...
# Is your number 50?
# Type 'h' if my guess is too high, 'l' if too low, or 'c' if correct:  h
# Is your number 25?
# Type 'h' if my guess is too high, 'l' if too low, or 'c' if correct:  h
# Is your number 12?
# Type 'h' if my guess is too high, 'l' if too low, or 'c' if correct:  h
# Is your number 6?
# Type 'h' if my guess is too high, 'l' if too low, or 'c' if correct:  l
# Is your number 9?
# Type 'h' if my guess is too high, 'l' if too low, or 'c' if correct:  h
# Is your number 7?
# Type 'h' if my guess is too high, 'l' if too low, or 'c' if correct:  c
# Great! I guessed your number in 6 attempts.
